# %% [markdown]
# # Lecture : Graph Convolutional Networks
#
# ## Lab 02 : GCNs -- Exercise
#
# ### Xavier Bresson, Nian Liu
#
# Kipf, Welling, Semi-supervised classification with graph convolutional networks, 2016
# https://arxiv.org/pdf/1609.02907.pdf

# %%
# For Google Colaboratory
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/CS5284_2024_codes/codes/08_Graph_Convnets'
    print(path_to_file)
    # change current path to the folder containing "path_to_file"
    os.chdir(path_to_file)
    # !pwd
    # !pip install dgl==1.0.0 # Install DGL

# %%
# Libraries
import dgl
from dgl.data import MiniGCDataset
import matplotlib.pyplot as plt
import networkx as nx
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import time

# %% [markdown]
# # Visualize the artifical graph dataset used in this notebook

# %%
dataset = MiniGCDataset(8, 10, 20) # DGL artificial dataset

# visualise the 8 classes of graphs
for c in range(8):
    graph, label = dataset[c] 
    #fig, ax = plt.subplots()
    fig, ax = plt.subplots(figsize=(4,4))
    nx.draw(graph.to_networkx(), ax=ax)
    ax.set_title('Class: {:d}'.format(label))
    plt.show()

# %% [markdown]
# # Generate train, val and test datasets

# %% [markdown]
# ## Question 1: Add a node feature with the in-degree node
#
# Hints: You may use function `.in_degrees()`, `.view()`, `.float()`

# %%
# Add node features to graphs
def add_node_features(dataset):
    for (graph,_) in dataset:
        ########################################
        # YOUR CODE STARTS
        # node feature = node in-degree
        # graph.ndata['feat'].size()=(num_nodes,1) and graph.ndata['feat'].type()=torch.FloatTensor
        ########################################
        graph.ndata['feat'] = graph.in_degrees().view(-1, 1).float() # node feat is in-degree
        ########################################
        # YOUR CODE ENDS
        ########################################
    return dataset

# Generate graph datasets
trainset = MiniGCDataset(350, 10, 20)
testset = MiniGCDataset(100, 10, 20)
valset = MiniGCDataset(100, 10, 20)
trainset = add_node_features(trainset)
testset = add_node_features(testset)
valset = add_node_features(valset)
print(trainset[0])
# Out:
# (Graph(num_nodes=15, num_edges=45,
#       ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#       edata_schemes={}), tensor(0))

# %% [markdown]
# ## Question 2: Define the collate function to generate a batch of DGL graphs and test it
#
# Batch a collection of DGL graphs into one graph for more efficient computation.
#
# Hints: You may use the DGL module [dgl.batch()](https://docs.dgl.ai/generated/dgl.batch.html#dgl.batch).

# %%
# collate function prepares a batch of graphs and labels 
def collate(samples):
    # Input sample is a list of pairs (graph, label)
    graphs, labels = map(list, zip(*samples)) # "graphs" is a list of "batch_size" DGL graphs
                                              # "labels" is a list of "batch_size" class labels
    ########################################
    # YOUR CODE STARTS
    # Create the DGL batch of graphs, which is equivalent to build a block diagonal matrix with all graphs in the batch
    ########################################
    batch_graphs = dgl.batch(graphs)    # batch of graphs
    ########################################
    # YOUR CODE ENDS
    ########################################
    batch_labels = torch.tensor(labels) # batch of labels
    return batch_graphs, batch_labels

# Generate a batch of graphs
batch_size = 10
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, collate_fn=collate)
batch_graphs, batch_labels = list(train_loader)[0]
print(batch_graphs)
print(batch_labels)
batch_x = batch_graphs.ndata['feat']
print('batch_x:',batch_x.size())
# Out:
# Graph(num_nodes=114, num_edges=570,
#       ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#       edata_schemes={})
# tensor([7, 4, 0, 7, 5, 4, 1, 3, 3, 4])
# batch_x: torch.Size([114, 1])

# %% [markdown]
# ## Question 3: Design the class of GCN networks with DGL
#
# Node update equation:
# \begin{eqnarray}
# h_i^{\ell+1} &=& h_i^{\ell} + \text{ReLU} \left( \frac{1}{\sqrt{d_i}} \sum_{j\sim i} \frac{1}{\sqrt{d_j}} W^\ell h_j^{\ell} \right)
# \end{eqnarray}
#
# Instructions:
#
# Step 1: Pass node feature and edge features along edges (src/j => dst/i) in `message_func()`.
#   - `edges.src['xx']` is to pick the feature 'xx' from the source nodes of edges.
#
# Step 2: Send `reduce_func()` collects all messages={Whj, dj} to node dst/i with Step 1.
#   - `nodes.mailbox['yy']` is to gather the feature 'yy' from neighbor nodes.

# %%
# MLP layer for classification
class MLP_layer(nn.Module): 
    
    def __init__(self, input_dim, output_dim, L=2): # L = nb of hidden layers
        super(MLP_layer, self).__init__()
        list_FC_layers = [ nn.Linear( input_dim, input_dim, bias=True ) for l in range(L) ]
        list_FC_layers.append(nn.Linear( input_dim, output_dim , bias=True ))
        self.FC_layers = nn.ModuleList(list_FC_layers)
        self.L = L
        
    def forward(self, x):
        y = x
        for l in range(self.L):
            y = self.FC_layers[l](y)
            y = torch.relu(y)
        y = self.FC_layers[self.L](y)
        return y

        
# class of GatedGCN layer  
class GCN_layer(nn.Module):
    
    def __init__(self, input_dim, output_dim):
        super(GCN_layer, self).__init__()
        self.W = nn.Linear(input_dim, output_dim, bias=True)
        
    # Step 1 of message-passing with DGL: 
    #   Node feature and edge features are passed along edges (src/j => dst/i) 
    def message_func(self, edges):
        ########################################
        # YOUR CODE STARTS
        # Step 1: Pass the messages Wh_j and d_j (in-degree_j) to the node i
        ########################################
        Whj = edges.src['Wh']
        dj = edges.src['d']
        ########################################
        # YOUR CODE ENDS
        ########################################
        return {'Whj' : Whj, 'dj' : dj}

    # Step 2 of message-passing with DGL: 
    #   Reduce function collects all messages={Whj, dj} sent to node dst/i with Step 1
    def reduce_func(self, nodes):
        ########################################
        # YOUR CODE STARTS
        # Step 2: Node i receives messages Wh_j and d_j (in-degree_j) 
        ########################################
        Whj = nodes.mailbox['Whj']
        dj = nodes.mailbox['dj']
        ########################################
        # YOUR CODE ENDS
        ########################################
        inv_sqrt_dj = torch.pow(dj, -0.5) # 1/sqrt(d_j)
        h = torch.sum( inv_sqrt_dj * Whj, dim=1 ) # hi = sum_j 1/sqrt(d_j) * Bhj 
        return {'h' : h} # return update node feature hi

    def forward(self, g, h):
        h_in = h # residual connection
        g.ndata['Wh'] = self.W(h) # linear transformation 
        d = g.in_degrees().view(-1, 1).float() # in-degree d_i
        g.ndata['d'] = d
        g.update_all(self.message_func,self.reduce_func) # update the node feature with DGL
        h = g.ndata['h'] # collect the node output of graph convolution
        inv_sqrt_d = torch.pow(d, -0.5) # 1/ sqrt(d_i)
        h = inv_sqrt_d * h # h_i / sqrt(d_i)
        h = torch.relu(h) # non-linear activation
        h = h_in + h # residual connection
        return h
    
    
class GCN_net(nn.Module):
    
    def __init__(self, net_parameters):
        super(GCN_net, self).__init__()
        input_dim = net_parameters['input_dim']
        hidden_dim = net_parameters['hidden_dim']
        output_dim = net_parameters['output_dim']
        L = net_parameters['L']
        self.embedding_h = nn.Linear(input_dim, hidden_dim)
        self.GCN_layers = nn.ModuleList([ GCN_layer(hidden_dim, hidden_dim) for _ in range(L) ]) 
        self.MLP_layer = MLP_layer(hidden_dim, output_dim)
        
    def forward(self, g, h):
        
        # input embedding
        h = self.embedding_h(h)
        
        # graph convnet layers
        for GCNlayer in self.GCN_layers:
            h = GCNlayer(g,h)
        
        # MLP classifier
        g.ndata['h'] = h
        y = dgl.mean_nodes(g,'h')
        y = self.MLP_layer(y)
        
        return y    
    
    def loss(self, y_scores, y_labels):
        loss = nn.CrossEntropyLoss()(y_scores, y_labels)
        return loss        
        
    def accuracy(self, scores, targets):
        scores = scores.detach().argmax(dim=1)
        acc = (scores==targets).float().sum().item()
        return acc
    
    def update(self, lr):       
        update = torch.optim.Adam( self.parameters(), lr=lr )
        return update


# Instantiate one network (testing)
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 128
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 4
net = GCN_net(net_parameters)
print(net)

def display_num_param(net):
    nb_param = 0
    for param in net.parameters():
        nb_param += param.numel()
    print('Number of parameters: {} ({:.2f} million)'.format(nb_param, nb_param/1e6))
    return nb_param/1e6
_ = display_num_param(net)
# Out:
# GCN_net(
#   (embedding_h): Linear(in_features=1, out_features=128, bias=True)
#   (GCN_layers): ModuleList(
#     (0-3): 4 x GCN_layer(
#       (W): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (MLP_layer): MLP_layer(
#     (FC_layers): ModuleList(
#       (0-1): 2 x Linear(in_features=128, out_features=128, bias=True)
#       (2): Linear(in_features=128, out_features=8, bias=True)
#     )
#   )
# )
# Number of parameters: 100360 (0.10 million)

# %% [markdown]
# # Train the network

# %%
def run_one_epoch(net, data_loader, train=True):
    if train:
        net.train()
    else:
        net.eval()
    epoch_loss = 0
    epoch_acc = 0
    nb_data = 0
    gpu_mem = 0
    for iter, (batch_graphs, batch_labels) in enumerate(data_loader):
        batch_x = batch_graphs.ndata['feat']
        batch_labels = batch_labels
        batch_scores = net.forward(batch_graphs, batch_x)
        loss = net.loss(batch_scores, batch_labels)
        if train:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        epoch_loss += loss.detach().item()
        epoch_acc += net.accuracy(batch_scores,batch_labels)
        nb_data += batch_labels.size(0)
    epoch_loss /= (iter + 1)
    epoch_acc /= nb_data
    return epoch_loss, epoch_acc 


# dataset loaders
train_loader = DataLoader(trainset, batch_size=50, shuffle=True, collate_fn=collate)
test_loader = DataLoader(testset, batch_size=50, shuffle=False, collate_fn=collate)
val_loader = DataLoader(valset, batch_size=50, shuffle=False, drop_last=False, collate_fn=collate)

# Instantiate one network
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 128
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 4
net = GCN_net(net_parameters)
display_num_param(net)

# optimizer
optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)

# training loop
for epoch in range(50):
    start = time.time()
    epoch_train_loss, epoch_train_acc = run_one_epoch(net, train_loader, True)
    with torch.no_grad(): 
        epoch_test_loss, epoch_test_acc = run_one_epoch(net, test_loader, False)
        epoch_val_loss, epoch_val_acc = run_one_epoch(net, val_loader, False)  
    print('Epoch {}, time {:.4f}, train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f}'.format(epoch, time.time()-start, epoch_train_loss, epoch_test_loss, epoch_val_loss))
    print('                      train_acc: {:.4f}, test_acc: {:.4f}, val_acc: {:.4f}'.format(epoch_train_acc, epoch_test_acc, epoch_val_acc))
# Out:
# Number of parameters: 100360 (0.10 million)
# Epoch 0, time 10.6429, train_loss: 2.1047, test_loss: 1.9817, val_loss: 1.9817
#                       train_acc: 0.1086, test_acc: 0.1200, val_acc: 0.1200
# Epoch 1, time 10.2764, train_loss: 1.9532, test_loss: 1.9572, val_loss: 1.9572
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 2, time 10.1863, train_loss: 1.9275, test_loss: 1.9227, val_loss: 1.9227
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 3, time 10.0256, train_loss: 1.8955, test_loss: 1.8954, val_loss: 1.8954
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 4, time 9.9248, train_loss: 1.8789, test_loss: 1.8767, val_loss: 1.8767
#                       train_acc: 0.1229, test_acc: 0.1200, val_acc: 0.1200
# Epoch 5, time 10.0417, train_loss: 1.8543, test_loss: 1.8601, val_loss: 1.8601
#                       train_acc: 0.1486, test_acc: 0.2200, val_acc: 0.2200
# Epoch 6, time 9.9546, train_loss: 1.8396, test_loss: 1.8401, val_loss: 1.8401
#                       train_acc: 0.2057, test_acc: 0.2200, val_acc: 0.2200
# Epoch 7, time 9.5341, train_loss: 1.8183, test_loss: 1.8176, val_loss: 1.8176
#                       train_acc: 0.3029, test_acc: 0.3800, val_acc: 0.3800
# Epoch 8, time 9.6982, train_loss: 1.7955, test_loss: 1.7950, val_loss: 1.7950
#                       train_acc: 0.3629, test_acc: 0.3800, val_acc: 0.3800
# Epoch 9, time 10.0290, train_loss: 1.7733, test_loss: 1.7739, val_loss: 1.7739
#                       train_acc: 0.3686, test_acc: 0.3800, val_acc: 0.3800
# Epoch 10, time 9.9350, train_loss: 1.7493, test_loss: 1.7474, val_loss: 1.7474
#                       train_acc: 0.3800, test_acc: 0.4100, val_acc: 0.4100
# Epoch 11, time 9.8530, train_loss: 1.7238, test_loss: 1.7208, val_loss: 1.7208
#                       train_acc: 0.4057, test_acc: 0.4100, val_acc: 0.4100
# Epoch 12, time 9.9167, train_loss: 1.6986, test_loss: 1.6959, val_loss: 1.6959
#                       train_acc: 0.3943, test_acc: 0.4100, val_acc: 0.4100
# Epoch 13, time 9.5865, train_loss: 1.6727, test_loss: 1.6666, val_loss: 1.6666
#                       train_acc: 0.4971, test_acc: 0.5600, val_acc: 0.5600
# Epoch 14, time 9.9120, train_loss: 1.6419, test_loss: 1.6387, val_loss: 1.6387
#                       train_acc: 0.5314, test_acc: 0.5600, val_acc: 0.5600
# Epoch 15, time 9.4784, train_loss: 1.6146, test_loss: 1.6098, val_loss: 1.6098
#                       train_acc: 0.5600, test_acc: 0.5600, val_acc: 0.5600
# Epoch 16, time 9.6106, train_loss: 1.5841, test_loss: 1.5785, val_loss: 1.5785
#                       train_acc: 0.5343, test_acc: 0.5500, val_acc: 0.5500
# Epoch 17, time 9.8418, train_loss: 1.5531, test_loss: 1.5496, val_loss: 1.5496
#                       train_acc: 0.5743, test_acc: 0.5600, val_acc: 0.5600
# Epoch 18, time 9.8043, train_loss: 1.5242, test_loss: 1.5198, val_loss: 1.5198
#                       train_acc: 0.5486, test_acc: 0.5600, val_acc: 0.5600
# Epoch 19, time 9.6378, train_loss: 1.5036, test_loss: 1.5021, val_loss: 1.5021
#                       train_acc: 0.5800, test_acc: 0.5600, val_acc: 0.5600
# Epoch 20, time 9.8393, train_loss: 1.4672, test_loss: 1.4668, val_loss: 1.4668
#                       train_acc: 0.5743, test_acc: 0.6800, val_acc: 0.6800
# Epoch 21, time 9.9364, train_loss: 1.4362, test_loss: 1.4317, val_loss: 1.4317
#                       train_acc: 0.7057, test_acc: 0.7100, val_acc: 0.7100
# Epoch 22, time 9.9413, train_loss: 1.4050, test_loss: 1.4032, val_loss: 1.4032
#                       train_acc: 0.7086, test_acc: 0.6800, val_acc: 0.6800
# Epoch 23, time 9.8190, train_loss: 1.3728, test_loss: 1.3762, val_loss: 1.3762
#                       train_acc: 0.7086, test_acc: 0.6800, val_acc: 0.6800
# Epoch 24, time 9.7428, train_loss: 1.3402, test_loss: 1.3389, val_loss: 1.3389
#                       train_acc: 0.6971, test_acc: 0.6800, val_acc: 0.6800
# Epoch 25, time 9.5878, train_loss: 1.3053, test_loss: 1.3081, val_loss: 1.3081
#                       train_acc: 0.7143, test_acc: 0.7100, val_acc: 0.7100
# Epoch 26, time 9.8243, train_loss: 1.2672, test_loss: 1.2727, val_loss: 1.2727
#                       train_acc: 0.7171, test_acc: 0.6800, val_acc: 0.6800
# Epoch 27, time 9.6560, train_loss: 1.2350, test_loss: 1.2411, val_loss: 1.2411
#                       train_acc: 0.7086, test_acc: 0.7100, val_acc: 0.7100
# Epoch 28, time 9.7991, train_loss: 1.2040, test_loss: 1.2046, val_loss: 1.2046
#                       train_acc: 0.7171, test_acc: 0.6800, val_acc: 0.6800
# Epoch 29, time 9.5498, train_loss: 1.1674, test_loss: 1.1705, val_loss: 1.1705
#                       train_acc: 0.7057, test_acc: 0.6800, val_acc: 0.6800
# Epoch 30, time 9.6896, train_loss: 1.1318, test_loss: 1.1468, val_loss: 1.1468
#                       train_acc: 0.7229, test_acc: 0.6900, val_acc: 0.6900
# Epoch 31, time 10.1190, train_loss: 1.1016, test_loss: 1.1149, val_loss: 1.1149
#                       train_acc: 0.7143, test_acc: 0.6800, val_acc: 0.6800
# Epoch 32, time 9.8919, train_loss: 1.0673, test_loss: 1.0728, val_loss: 1.0728
#                       train_acc: 0.7143, test_acc: 0.6800, val_acc: 0.6800
# Epoch 33, time 9.8367, train_loss: 1.0258, test_loss: 1.0356, val_loss: 1.0356
#                       train_acc: 0.7114, test_acc: 0.6800, val_acc: 0.6800
# Epoch 34, time 9.7549, train_loss: 0.9882, test_loss: 1.0152, val_loss: 1.0152
#                       train_acc: 0.7114, test_acc: 0.7100, val_acc: 0.7100
# Epoch 35, time 9.5973, train_loss: 0.9563, test_loss: 0.9723, val_loss: 0.9723
#                       train_acc: 0.7200, test_acc: 0.6800, val_acc: 0.6800
# Epoch 36, time 9.9553, train_loss: 0.9263, test_loss: 0.9480, val_loss: 0.9480
#                       train_acc: 0.7371, test_acc: 0.7900, val_acc: 0.7900
# Epoch 37, time 9.9019, train_loss: 0.8982, test_loss: 0.9162, val_loss: 0.9162
#                       train_acc: 0.7514, test_acc: 0.7900, val_acc: 0.7900
# Epoch 38, time 9.7420, train_loss: 0.8773, test_loss: 0.9020, val_loss: 0.9020
#                       train_acc: 0.7257, test_acc: 0.7100, val_acc: 0.7100
# Epoch 39, time 9.7658, train_loss: 0.8559, test_loss: 0.8680, val_loss: 0.8680
#                       train_acc: 0.7286, test_acc: 0.7100, val_acc: 0.7100
# Epoch 40, time 10.0439, train_loss: 0.8266, test_loss: 0.8494, val_loss: 0.8494
#                       train_acc: 0.7429, test_acc: 0.8000, val_acc: 0.8000
# Epoch 41, time 9.9128, train_loss: 0.8010, test_loss: 0.8208, val_loss: 0.8208
#                       train_acc: 0.7971, test_acc: 0.7800, val_acc: 0.7800
# Epoch 42, time 9.8832, train_loss: 0.7774, test_loss: 0.8120, val_loss: 0.8120
#                       train_acc: 0.7343, test_acc: 0.7100, val_acc: 0.7100
# Epoch 43, time 9.7469, train_loss: 0.7605, test_loss: 0.7866, val_loss: 0.7866
#                       train_acc: 0.7686, test_acc: 0.7900, val_acc: 0.7900
# Epoch 44, time 9.7119, train_loss: 0.7262, test_loss: 0.7630, val_loss: 0.7630
#                       train_acc: 0.7686, test_acc: 0.7300, val_acc: 0.7300
# Epoch 45, time 9.8100, train_loss: 0.7109, test_loss: 0.7478, val_loss: 0.7478
#                       train_acc: 0.7800, test_acc: 0.7900, val_acc: 0.7900
# Epoch 46, time 9.8692, train_loss: 0.6970, test_loss: 0.7404, val_loss: 0.7404
#                       train_acc: 0.8143, test_acc: 0.8200, val_acc: 0.8200
# Epoch 47, time 9.7929, train_loss: 0.6845, test_loss: 0.7131, val_loss: 0.7131
#                       train_acc: 0.7943, test_acc: 0.7900, val_acc: 0.7900
# Epoch 48, time 9.6033, train_loss: 0.6655, test_loss: 0.6986, val_loss: 0.6986
#                       train_acc: 0.7686, test_acc: 0.7100, val_acc: 0.7100
# Epoch 49, time 9.7415, train_loss: 0.6506, test_loss: 0.6946, val_loss: 0.6946
#                       train_acc: 0.7943, test_acc: 0.7900, val_acc: 0.7900
